# %%
import pandas as pd

# %%
url="https://data.moenv.gov.tw/api/v2/aqx_p_02?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate%20desc&format=CSV"

# %%
df=pd.read_csv(url).dropna()
df
# Out:
#    site county  pm25  datacreationdate itemunit
# 0    大城    彰化縣  17.0  2024-02-22 20:00    μg/m3
# 1   富貴角    新北市   1.0  2024-02-22 20:00    μg/m3
# 2    麥寮    雲林縣  15.0  2024-02-22 20:00    μg/m3
# 3    關山    臺東縣   6.0  2024-02-22 20:00    μg/m3
# 4    馬公    澎湖縣   6.0  2024-02-22 20:00    μg/m3
# ..  ...    ...   ...               ...      ...
# 73   土城    新北市   3.0  2024-02-22 20:00    μg/m3
# 74   新店    新北市   0.0  2024-02-22 20:00    μg/m3
# 75   萬里    新北市   6.0  2024-02-22 20:00    μg/m3
# 76   汐止    新北市   1.0  2024-02-22 20:00    μg/m3
# 77   基隆    基隆市   3.0  2024-02-22 20:00    μg/m3
#
# [77 rows x 5 columns]

# %% [markdown]
# ### 取cloumn&values

# %%
columns=df.columns.tolist()
columns
# Out:
# ['site', 'county', 'pm25', 'datacreationdate', 'itemunit']

# %%
values=df.values.tolist()
values
# Out:
# [['大城', '彰化縣', 17.0, '2024-02-22 20:00', 'μg/m3'],
#  ['富貴角', '新北市', 1.0, '2024-02-22 20:00', 'μg/m3'],
#  ['麥寮', '雲林縣', 15.0, '2024-02-22 20:00', 'μg/m3'],
#  ['關山', '臺東縣', 6.0, '2024-02-22 20:00', 'μg/m3'],
#  ['馬公', '澎湖縣', 6.0, '2024-02-22 20:00', 'μg/m3'],
#  ['金門', '金門縣', 18.0, '2024-02-22 20:00', 'μg/m3'],
#  ['馬祖', '連江縣', 5.0, '2024-02-22 20:00', 'μg/m3'],
#  ['埔里', '南投縣', 25.0, '2024-02-22 20:00', 'μg/m3'],
#  ['復興', '高雄市', 12.0, '2024-02-22 20:00', 'μg/m3'],
#  ['永和', '新北市', 3.0, '2024-02-22 20:00', 'μg/m3'],
#  ['竹山', '南投縣', 29.0, '2024-02-22 20:00', 'μg/m3'],
#  ['中壢', '桃園市', 10.0, '2024-02-22 20:00', 'μg/m3'],
#  ['三重', '新北市', 8.0, '2024-02-22 20:00', 'μg/m3'],
#  ['冬山', '宜蘭縣', 6.0, '2024-02-22 20:00', 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 7.0, '2024-02-22 20:00', 'μg/m3'],
#  ['陽明', '臺北市', 2.0, '2024-02-22 20:00', 'μg/m3'],
#  ['花蓮', '花蓮縣', 6.0, '2024-02-22 20:00', 'μg/m3'],
#  ['臺東', '臺東縣', 7.0, '2024-02-22 20:00', 'μg/m3'],
#  ['恆春', '屏東縣', 6.0, '2024-02-22 20:00', 'μg/m3'],
#  ['潮州', '屏東縣', 16.0, '2024-02-22 20:00', 'μg/m3'],
#  ['屏東', '屏東縣', 11.0, '2024-02-22 20:00', 'μg/m3'],
#  ['小港', '高雄市', 14.0, '2024-02-22 20:00', 'μg/m3'],
#  ['前鎮', '高雄市', 15.0, '2024-02-22 20:00', 'μg/m3'],
#  ['前金', '高雄市', 14.0, '2024-02-22 20:00', 'μg/m3'],
#  ['左營', '高雄市', 14.0, '2024-02-22 20:00', 'μg/m3'],
#  ['楠梓', '高雄市', 16.0, '2024-02-22 20:00', 'μg/m3'],
#  ['林園', '高雄市', 14.0, '2024-02-22 20:00', 'μg/m3'],
#  ['大寮', '高雄市', 13.0, '2024-02-22 20:00', 'μg/m3'],
#  ['鳳山', '高雄市', 19.0, '2024-02-22 20:00', 'μg/m3'],
#  ['仁武', '高雄市', 16.0, '2024-02-22 20:00', 'μg/m3'],
#  ['橋頭', '高雄市', 13.0, '2024-02-22 20:00', 'μg/m3'],
#  ['美濃', '高雄市', 12.0, '2024-02-22 20:00', 'μg/m3'],
#  ['臺南', '臺南市', 19.0, '2024-02-22 20:00', 'μg/m3'],
#  ['安南', '臺南市', 22.0, '2024-02-22 20:00', 'μg/m3'],
#  ['善化', '臺南市', 20.0, '2024-02-22 20:00', 'μg/m3'],
#  ['新營', '臺南市', 14.0, '2024-02-22 20:00', 'μg/m3'],
#  ['嘉義', '嘉義市', 22.0, '2024-02-22 20:00', 'μg/m3'],
#  ['臺西', '雲林縣', 9.0, '2024-02-22 20:00', 'μg/m3'],
#  ['朴子', '嘉義縣', 18.0, '2024-02-22 20:00', 'μg/m3'],
#  ['新港', '嘉義縣', 18.0, '2024-02-22 20:00', 'μg/m3'],
#  ['崙背', '雲林縣', 12.0, '2024-02-22 20:00', 'μg/m3'],
#  ['斗六', '雲林縣', 24.0, '2024-02-22 20:00', 'μg/m3'],
#  ['南投', '南投縣', 22.0, '2024-02-22 20:00', 'μg/m3'],
#  ['二林', '彰化縣', 16.0, '2024-02-22 20:00', 'μg/m3'],
#  ['線西', '彰化縣', 16.0, '2024-02-22 20:00', 'μg/m3'],
#  ['彰化', '彰化縣', 13.0, '2024-02-22 20:00', 'μg/m3'],
#  ['西屯', '臺中市', 22.0, '2024-02-22 20:00', 'μg/m3'],
#  ['忠明', '臺中市', 15.0, '2024-02-22 20:00', 'μg/m3'],
#  ['大里', '臺中市', 23.0, '2024-02-22 20:00', 'μg/m3'],
#  ['沙鹿', '臺中市', 11.0, '2024-02-22 20:00', 'μg/m3'],
#  ['豐原', '臺中市', 19.0, '2024-02-22 20:00', 'μg/m3'],
#  ['三義', '苗栗縣', 23.0, '2024-02-22 20:00', 'μg/m3'],
#  ['頭份', '苗栗縣', 8.0, '2024-02-22 20:00', 'μg/m3'],
#  ['新竹', '新竹市', 5.0, '2024-02-22 20:00', 'μg/m3'],
#  ['竹東', '新竹縣', 5.0, '2024-02-22 20:00', 'μg/m3'],
#  ['湖口', '新竹縣', 9.0, '2024-02-22 20:00', 'μg/m3'],
#  ['龍潭', '桃園市', 2.0, '2024-02-22 20:00', 'μg/m3'],
#  ['平鎮', '桃園市', 4.0, '2024-02-22 20:00', 'μg/m3'],
#  ['觀音', '桃園市', 5.0, '2024-02-22 20:00', 'μg/m3'],
#  ['大園', '桃園市', 0.0, '2024-02-22 20:00', 'μg/m3'],
#  ['桃園', '桃園市', 1.0, '2024-02-22 20:00', 'μg/m3'],
#  ['大同', '臺北市', 17.0, '2024-02-22 20:00', 'μg/m3'],
#  ['松山', '臺北市', 5.0, '2024-02-22 20:00', 'μg/m3'],
#  ['古亭', '臺北市', 1.0, '2024-02-22 20:00', 'μg/m3'],
#  ['萬華', '臺北市', 4.0, '2024-02-22 20:00', 'μg/m3'],
#  ['中山', '臺北市', 0.0, '2024-02-22 20:00', 'μg/m3'],
#  ['士林', '臺北市', 0.0, '2024-02-22 20:00', 'μg/m3'],
#  ['淡水', '新北市', 7.0, '2024-02-22 20:00', 'μg/m3'],
#  ['林口', '新北市', 5.0, '2024-02-22 20:00', 'μg/m3'],
#  ['菜寮', '新北市', 3.0, '2024-02-22 20:00', 'μg/m3'],
#  ['新莊', '新北市', 2.0, '2024-02-22 20:00', 'μg/m3'],
#  ['板橋', '新北市', 3.0, '2024-02-22 20:00', 'μg/m3'],
#  ['土城', '新北市', 3.0, '2024-02-22 20:00', 'μg/m3'],
#  ['新店', '新北市', 0.0, '2024-02-22 20:00', 'μg/m3'],
#  ['萬里', '新北市', 6.0, '2024-02-22 20:00', 'μg/m3'],
#  ['汐止', '新北市', 1.0, '2024-02-22 20:00', 'μg/m3'],
#  ['基隆', '基隆市', 3.0, '2024-02-22 20:00', 'μg/m3']]
